# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2 # Imported as opencv-python

print("TensorFlow Version:", tf.__version__)
print("NumPy Version:", np.__version__)

# Simple test to confirm NumPy and Matplotlib are working
# Creates and displays a random 10x10 matrix as an image
data = np.random.rand(10, 10)
plt.imshow(data, cmap='viridis')
plt.title("Matplotlib Test Image")
plt.show()

if 'cv2' in globals():
    print("OpenCV (cv2) imported successfully.")
else:
    print("OpenCV failed to import.")
# Out:
# WARNING:tensorflow:From c:\Users\hoshenghong\miniconda3\envs\CVE\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow Version: 2.15.0
# NumPy Version: 1.26.3
# OpenCV (cv2) imported successfully.
